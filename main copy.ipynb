# %% [markdown]
# # Imports and initialized some clients

# %%
import os
import re
import string
import numpy as np
import pandas as pd
import faiss
import json
import time
import requests


from tqdm import tqdm
tqdm.pandas()

import nltk
# nltk.download("punkt", quiet=True)
# nltk.download("stopwords", quiet=True)

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords as nltk_stopwords

from rank_bm25 import BM25Okapi
from sklearn.preprocessing import minmax_scale

from openai import OpenAI
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

import cohere
co = cohere.Client(os.getenv("COHERE_API_KEY"))

# %% [markdown]
# # Configurations

# %%
EMBED_MODEL = "text-embedding-3-small"   # cheap & solid
GEN_MODEL = "gpt-4o-mini"                # choose a chat model you have access to
FAISS_MODE = "cosine"                    # "cosine" or "similarity_score"
ALPHA = 0.8                              # semantic weight in fusion
TOP_K = 5                                # top docs to return after fusion
RERANK_TOP_K = 5                         # top docs after reranking

STOPWORDS = set(nltk_stopwords.words("english"))

# %% [markdown]
# # Utils

# %%
def preprocess_text(text: str):
    """Clean and normalize text by removing extra whitespace and fixing spacing around punctuation."""
    if pd.isna(text):
        return None
    text = str(text)
    if (text.startswith('"') and text.endswith('"')) or (text.startswith("'") and text.endswith("'")):
        text = text[1:-1].strip()
    text = re.sub(r'\s+', ' ', text)                    # collapse whitespace
    text = re.sub(r'([.,?!])\s*', r'\1 ', text)         # ensure space after punctuation
    text = re.sub(r'\s+([.,?!])', r'\1', text)          # remove space before punctuation
    return text.strip()


def embed_texts(texts, model: str = EMBED_MODEL, batch_size: int = 64):
    """Embed a list of texts in batches with progress bar."""
    embeddings = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Embedding batches"):
        batch = texts[i:i+batch_size]
        # Safety truncation for extreme inputs
        batch = [t[:10000] if len(t) > 10000 else t for t in batch]
        resp = client.embeddings.create(input=batch, model=model)
        batch_embeddings = [r.embedding for r in resp.data]
        embeddings.extend(batch_embeddings)
    return np.array(embeddings)


def build_faiss_index(df: pd.DataFrame, mode: str, save_path="sanity_llm_index.faiss"):
    emb = np.array(df["embedding"].tolist()).astype(np.float32)
    dim = emb.shape[1]

    # Map FAISS row index -> (Context, Response)
    id_to_meta = {i: {"Context": row["Context"], "Response": row["Response"]} 
                  for i, row in df.iterrows()}

    if mode == "cosine":
        faiss.normalize_L2(emb)
        index = faiss.IndexFlatIP(dim)
    elif mode == "similarity_score":
        index = faiss.IndexFlatL2(dim)
    else:
        raise ValueError("mode must be either 'cosine' or 'similarity_score'")

    index.add(emb)
    faiss.write_index(index, save_path)

    return index, id_to_meta


def load_faiss_db(df: pd.DataFrame, mode: str, save_path="sanity_llm_index.faiss"):
    try:
        index = faiss.read_index(save_path)
        id_to_meta = {i: {"Context": row["Context"], "Response": row["Response"]} 
                      for i, row in df.iterrows()}
    except:
        index, id_to_meta = build_faiss_index(df, mode, save_path)

    return index, id_to_meta

def GetSemanticScores(query: str, index, mode="cosine"):
    q_emb = np.array([get_embedding(query)], dtype=np.float32)
    if mode == "cosine":
        faiss.normalize_L2(q_emb)
        D, I = index.search(q_emb, k=index.ntotal)
        scores = D[0]  # higher is better
    else:
        D, I = index.search(q_emb, k=index.ntotal)
        scores = 1.0 / (D[0] + 1e-6)  # convert L2 to similarity
    return {int(I[0][i]): float(scores[i]) for i in range(len(I[0]))}


def GetBM25Score(query: str, bm25, stop_set):
    tokens = [t for t in word_tokenize(query.lower()) if t not in stop_set and t not in string.punctuation]
    scores = bm25.get_scores(tokens)  # aligned with corpus order
    return {i: float(s) for i, s in enumerate(scores)}


def FuseScores(query: str, bm25, index, mode="cosine", alpha=ALPHA, stop_set=STOPWORDS):
    bm25_scores = GetBM25Score(query, bm25, stop_set)
    semantic_scores = GetSemanticScores(query, index, mode=mode)

    doc_ids = list(bm25_scores.keys())
    bm25_vals = np.array([bm25_scores[doc_id] for doc_id in doc_ids])
    sem_vals = np.array([semantic_scores.get(doc_id, 0.0) for doc_id in doc_ids])

    # normalize [0,1]
    bm25_norm = minmax_scale(bm25_vals) if len(bm25_vals) > 1 else bm25_vals
    sem_norm = minmax_scale(sem_vals) if len(sem_vals) > 1 else sem_vals

    fused = alpha * sem_norm + (1 - alpha) * bm25_norm
    return doc_ids, fused


def generate_stepback_question(user_query: str):
    prompt = f"""
You are a helpful mental health assistant. Given a user's emotional/mental health concern,
write ONE insightful "stepback question" that helps the user reflect at a higher level.
User: {user_query}
Your single stepback question:""".strip()

    # Keep it a single-turn prompt
    resp = client.chat.completions.create(
        model=GEN_MODEL,
        messages=[{"role": "user", "content": prompt}],
        temperature=0.2,
        max_tokens=64
    )
    return resp.choices[0].message.content.strip()


def rerank_with_cohere(query: str, docs: list, top_k: int = RERANK_TOP_K):
    """Rerank a list of dicts [{'Context', 'Response'}] by scoring on their Context text, and return the dicts sorted."""
    if not docs:
        return []

    texts = [f"Context: {d['Context']}\nResponse: {d['Response']}" for d in docs]  # lightweight reranking on question only
    response = co.rerank(
        model="rerank-v3.5",
        query=query,
        documents=texts,
        top_n=min(top_k, len(texts)),
    )
    # Map back to dicts in reranked order
    reranked = [docs[r.index] for r in response.results]
    return reranked

def update_conversation_history(history, user_query, assistant_response, max_exchanges=5):
    # Separate system prompt and rest
    system_prompt = history[0]
    chat_turns = history[1:]

    # Add new turns
    chat_turns.append({"role": "user", "content": user_query})
    chat_turns.append({"role": "assistant", "content": assistant_response})

    # Keep only the last N exchanges
    if len(chat_turns) > max_exchanges * 2:
        chat_turns = chat_turns[-max_exchanges * 2:]

    # Combine and return
    return [system_prompt] + chat_turns

def build_generation_prompt(user_query: str, docs: list):
    """Formats the prompt for generation using retrieved contexts (Context + bulleted Responses)."""
    blocks = []
    for i, d in enumerate(docs, 1):
        blocks.append(f"Document {i}:\nQuestion: {d['Context']}\nAnswers:\n{d['Response']}")
    context_section = "\n\n".join(blocks)
    prompt = f"""You are a helpful and empathetic mental health assistant.
Use the provided Q&A knowledge to answer the user's question in a thoughtful, safe, and non-diagnostic way.
Cite insights from the answers implicitly (no numbers/links), and include supportive next steps (e.g., grounded coping strategies).
If urgent risk is implied, advise seeking immediate professional help or contacting local emergency services.

NOTE: Your Task is only to respond to the User Query related to mental health support. if the user query is not related to mental health support, respond with "I'm here to help with mental health support. This topic seems outside that scope."

--- Knowledge ---
{context_section}

--- User Query ---
{user_query}

--- Your Answer ---
"""
    return prompt


def generate_with_memory(user_query, conversation_history, client, final_docs, model="gpt-4o-mini"):
    """
    Generate a response with conversation memory.
    - user_query: raw user question
    - conversation_history: list of dicts [{"role": "...", "content": "..."}]
    - client: OpenAI client instance
    """
    prompts = build_generation_prompt(user_query, final_docs)
    response = client.chat.completions.create(
        model=model,
        messages=conversation_history + [{"role": "user", "content": prompts}],
        temperature=0.7,
        max_tokens=512
    )
    
    
    assistant_reply = response.choices[0].message.content.strip()
    # Update conversation history
    updated_history = update_conversation_history(
        conversation_history, 
        user_query, 
        assistant_reply
    )
    
    return assistant_reply, updated_history

def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],
        model=model
    )
    return response.data[0].embedding

# %% [markdown]
# # Load & preprocess data

# %%
raw1 = pd.read_json("data.json")
raw1.drop(columns=["instruction"], inplace=True, errors="ignore")
raw1.rename(columns={"input": "Context", "output": "Response"}, inplace=True)

# Load Marmikpandya dataset
raw2 = pd.read_json("combined_dataset.json", lines=True)

# Normalize schema (in case names differ, adjust if needed)
if "Context" not in raw2.columns or "Response" not in raw2.columns:
    # Example mapping if needed (adjust per schema of marmikpandya dataset)
    if "question" in raw2.columns and "answer" in raw2.columns:
        raw2.rename(columns={"question": "Context", "answer": "Response"}, inplace=True)

raw1["Context"] = raw1["Context"].apply(preprocess_text)
raw1["Response"] = raw1["Response"].apply(preprocess_text)

raw2["Context"] = raw2["Context"].apply(preprocess_text)
raw2["Response"] = raw2["Response"].apply(preprocess_text)

# Combine datasets
raw = pd.concat([raw1, raw2], ignore_index=True)

# Drop null/short responses
raw = raw.dropna(subset=["Response"])
raw = raw[raw["Response"].str.strip().str.len() >= 5]

# Drop duplicate (Context, Response) pairs only (keep same Context with multiple Responses)
raw = raw.drop_duplicates(subset=["Context", "Response"])

# Group: Context -> bulleted Responses
df_grouped = (
    raw.groupby("Context")["Response"]
       .apply(lambda xs: "\n".join(f"- {x}" for x in xs))
       .reset_index()
)

df_grouped["doc_id"] = df_grouped.index.astype(str)
# Save outputs
# raw.to_csv("CombinedRaw.csv", index=False)
df_grouped.to_csv("GroupedResponses.csv", index=False)

print("✅ Combined dataset saved: Combined_dataset.json & GroupedResponses.csv")
# Out:
# ✅ Combined dataset saved: Combined_dataset.json & GroupedResponses.csv

# %%
df_grouped = pd.read_csv("GroupedResponses.csv")
df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7410 entries, 0 to 7409
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Context   7410 non-null   object
#  1   Response  7410 non-null   object
#  2   doc_id    7410 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 173.8+ KB

# %% [markdown]
# # Set the embeddings and the BM25

# %%
from tqdm import tqdm
tqdm.pandas()  # enable .progress_apply

# BM25 on Questions only (Context)
documents = df_grouped["Context"].tolist()
tokenized = [
    [t for t in word_tokenize(doc.lower())
     if t not in STOPWORDS and t not in string.punctuation]
    for doc in tqdm(documents, desc="Tokenizing for BM25")
]
bm25 = BM25Okapi(tokenized)

# Embeddings on Q + A (Context + Response)
texts = [
    f"Question: {row['Context']}\nAnswer: {row['Response']}"
    for _, row in df_grouped.iterrows()
]
df_grouped["embedding"] = embed_texts(texts, batch_size=64).tolist()

# Save for later use
df_grouped.to_csv("GroupedResponsesWithEmbeddings.csv", index=False)

#FAISS index
index, id_to_meta = load_faiss_db(df_grouped, mode=FAISS_MODE)
# Out:
# ...
# Embedding batches: 100%|██████████| 116/116 [05:14<00:00,  2.71s/it]

# %%
# Load FAISS index, if you have saved first
df_grouped = pd.read_csv('GroupedResponsesWithEmbeddings.csv')
documents = df_grouped["Context"].tolist()
tokenized = [
    [t for t in word_tokenize(doc.lower())
     if t not in STOPWORDS and t not in string.punctuation]
    for doc in tqdm(documents, desc="Tokenizing for BM25")
]
bm25 = BM25Okapi(tokenized)
index, id_to_meta = load_faiss_db(df_grouped, mode=FAISS_MODE)
# Out:
# Tokenizing for BM25: 100%|██████████| 7410/7410 [00:02<00:00, 3260.89it/s]

# %%
# Retrieval function (BM25 + FAISS fusion) -> top dicts
def retrieve_top_docs(user_query: str, top_k: int = TOP_K):
    doc_ids, fused = FuseScores(user_query, bm25, index, mode=FAISS_MODE, alpha=ALPHA, stop_set=STOPWORDS)
    if len(doc_ids) == 0:
        return []
    top_idx = np.argsort(fused)[-top_k:][::-1]
    out = []
    for idx in top_idx:
        doc_id = doc_ids[idx]
        meta = id_to_meta[doc_id]
        out.append({"Context": meta["Context"], "Response": meta["Response"], "Score": float(fused[idx])})
    return out

# %% [markdown]
# # Example run (you can replace with your own query)

# %%
conversation_history = [
    {"role": "system", "content": "You are a helpful, supportive mental health assistant."}
]

user_query = "I've been having suicidal thoughts at night, sometimes even in the middle of the day. What should I do?"
stepback_question = generate_stepback_question(user_query)

top_user = retrieve_top_docs(user_query, top_k=TOP_K)
top_stepback = retrieve_top_docs(stepback_question, top_k=TOP_K)

# Combine + dedupe by Context (keep dicts)
seen = set()
combined = []
for d in top_user + top_stepback:
    ctx = d["Context"]
    if ctx not in seen:
        seen.add(ctx)
        combined.append(d)

# Rerank with Cohere (by Context) and keep dicts
final_docs = rerank_with_cohere(user_query, combined, top_k=RERANK_TOP_K)

# Build prompt and generate answer
# prompt = build_generation_prompt(user_query, final_docs)
reply, conversation_history = generate_with_memory(user_query, conversation_history, client, final_docs)

# Print results (short preview)
print("Retrieved docs (after rerank):", len(final_docs))
for i, d in enumerate(final_docs, 1):
    print(f"[{i}] Context: {d['Context']} Response: {d['Response']}")
print("\nAssistant:\n", reply, "\n")

print("Conversation History:\n")
print(conversation_history)
# Out:
# Retrieved docs (after rerank): 5
# [1] Context: I'm feeling really hopeless and suicidal. What should I do? Response: - It's important to take suicidal thoughts seriously and seek immediate help. Let's explore therapy and medication options to address your symptoms. We can also work on developing a safety plan and identifying supportive resources such as crisis lines and emergency services.
# [2] Context: I've been having negative thoughts and feelings about myself and others, and sometimes I even think about hurting myself. What should I do? Response: - It's important to take thoughts of self-harm seriously and to seek immediate help if you ever feel like you're in danger of hurting yourself. We can work on finding treatment options that may include therapy, medication, or a combination of both. It's important to also have a support system in place and to avoid isolating yourself. You are not alone in this and there are people who care about you and want to help.
# ...

# %% [markdown]
# Testing Set Generation

# %%
def process_query(user_query, conversation_history, client, test_set,
                  TOP_K=5, RERANK_TOP_K=3):
    """
    Process a user query with stepback reasoning, retrieval, rerank, and response generation.
    Updates conversation_history and test_set in place.

    Args:
        user_query (str): The input query from the user.
        conversation_history (list): Chat history (list of dicts with role + content).
        client: LLM client object (for generate_with_memory).
        test_set (list): A list to append test cases to.
        TOP_K (int): Number of docs to retrieve before rerank.
        RERANK_TOP_K (int): Number of top docs to keep after rerank.

    Returns:
        reply (str): The assistant’s generated response.
        conversation_history (list): Updated conversation history.
    """

    # Stepback question
    stepback_question = generate_stepback_question(user_query)

    # Retrieve docs
    top_user = retrieve_top_docs(user_query, top_k=TOP_K)
    top_stepback = retrieve_top_docs(stepback_question, top_k=TOP_K)

    # Combine + dedupe
    seen = set()
    combined = []
    for d in top_user + top_stepback:
        ctx = d["Context"]
        if ctx not in seen:
            seen.add(ctx)
            combined.append(d)

    # Rerank
    final_docs = rerank_with_cohere(user_query, combined, top_k=RERANK_TOP_K)

    # Generate response with memory
    reply, conversation_history = generate_with_memory(
        user_query, conversation_history, client, final_docs
    )

    # Prepare test_set entry
    history_text = "\n".join([f"{m['role']}: {m['content']}" for m in conversation_history[:len(conversation_history)-1]])

    contexts = [f"Context: {d['Context']} | Response: {d['Response']}" for d in final_docs]

    test_set.append({
        "Question": history_text,
        "Answer": reply,
        "Context": contexts,
        "user_query": user_query,
    })

    return reply, conversation_history, final_docs

# %%
def build_closed_book_prompt(user_query: str) -> str:
    """Formats a closed-book prompt (no retrieved docs)."""
    prompt = f"""You are a helpful and empathetic mental health assistant.
Answer the user's question in a thoughtful, safe, and non-diagnostic way.
Base your answer only on your general knowledge and conversation context provided in the chat history.
Offer supportive next steps (e.g., grounded coping strategies), and avoid making clinical diagnoses.
If urgent risk is implied, advise seeking immediate professional help or contacting local emergency services.
If the query is not about mental health support, reply: "I'm here to help with mental health support. This topic seems outside that scope."

--- User Query ---
{user_query}

--- Your Answer ---"""
    return prompt


def generate_closed_book(user_query, conversation_history, client, model="gpt-4o-mini"):
    """
    Closed-book generation: no retrieval, no reranking;
    """
    prompt = build_closed_book_prompt(user_query)
    response = client.chat.completions.create(
        model=model,
        messages=conversation_history + [{"role": "user", "content": prompt}],
        temperature=0.7,
        max_tokens=512
    )
    assistant_reply = response.choices[0].message.content.strip()
    updated_history = update_conversation_history(conversation_history, user_query, assistant_reply)
    return assistant_reply, updated_history


def process_query_closed_book(user_query, conversation_history, client, test_set_no_rag):
    """
    Process a user query in closed-book mode (no RAG). Updates history and test_set.
    Returns (reply, conversation_history).
    """

    # Generate without any retrieved docs
    reply, conversation_history = generate_closed_book(
        user_query=user_query,
        conversation_history=conversation_history,
        client=client,
    )

    # Prepare test_set entry (keep schema consistent with RAG run)
    history_text = "\n".join([f"{m['role']}: {m['content']}" for m in conversation_history[:len(conversation_history)-1]])

    test_set_no_rag.append({
        "Question": history_text,
        "Answer": reply,
        "user_query": user_query,
    })

    return reply, conversation_history

# %%
def generate_patient_reply(client, conversation_history, turn_num):
    """
    Generate the next patient query based on the ongoing conversation.
    """
    prompt = f"""
    You are a patient with mental health struggles.

    ONLY speak as the patient, expressing your struggles and asking for help.

    This is turn {turn_num} of the conversation.

    If turn == 1:
    • Start a new and unique conversation. 
    • Introduce yourself naturally as a patient (this identity must be remembered in future turns).
    • Describe one mental health problem (randomly choose from: anxiety, depression, burnout, loneliness, self-esteem issues, or other related concerns).
    • Be authentic, detailed, and emotional — avoid generic phrasing.

    If turn > 1:
    • Continue speaking as the same patient identity you introduced in turn 1.
    • Reply naturally to the last assistant response (remember: you are the patient asking for help, NOT giving help).
    • Do NOT repeat the assistant’s suggestions or your own previous statements.
    • Do NOT try to complete or continue the assistant’s unfinished thoughts — only share your own perspective.
    • Stay authentic, emotional, and vulnerable. Keep sharing your struggles, feelings, and difficulties as a patient.

    Continue this conversation if turn > 1, OR start it if turn == 1:
    """

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}] + conversation_history[1:],
        temperature=0.7,
        max_tokens=200
    )
    return response.choices[0].message.content.strip()


def simulate_patient_conversation(client, conversation_history, test_set, conversation_history_no_rag, test_set_no_rag,
                                  turns=5, TOP_K=5, RERANK_TOP_K=3):
    """
    Simulate a flowing conversation (user ↔ assistant) for `turns` turns.
    The patient query is generated based on assistant's last response.
    """

    # First patient query
    first_query = generate_patient_reply(client, conversation_history, turn_num=1)
    print(f"\nTurn 1 | Patient: {first_query}\n")

    reply, conversation_history, final_docs = process_query(
        first_query,
        conversation_history,
        client,
        test_set,
        TOP_K=TOP_K,
        RERANK_TOP_K=RERANK_TOP_K
    )
    print(f"Assistant: {reply}\n")

    # Next turns
    for t in range(2, turns + 1):
        # patient generates reply in flow of conversation
        patient_query = generate_patient_reply(client, conversation_history, turn_num=t)
        print(f"\nTurn {t} | Patient: {patient_query}\n")

        reply, conversation_history, final_docs = process_query(
            patient_query,
            conversation_history,
            client,
            test_set,
            TOP_K=TOP_K,
            RERANK_TOP_K=RERANK_TOP_K
        )

        print(f"Assistant: {reply}\n")
    
    # No RAG part
    reply, conversation_history_no_rag = process_query_closed_book(
        first_query,
        conversation_history_no_rag,
        client,
        test_set_no_rag
    )
    print(f"Assistant: {reply}\n")

    for t in range(2, turns + 1):
        # patient generates reply in flow of conversation
        patient_query = generate_patient_reply(client, conversation_history_no_rag, turn_num=t)
        print(f"\nTurn {t} | Patient: {patient_query}\n")

        reply, conversation_history_no_rag = process_query_closed_book(
            patient_query,
            conversation_history_no_rag,
            client,
            test_set_no_rag
        )

        print(f"Assistant: {reply}\n")

    return conversation_history, test_set, conversation_history_no_rag, test_set_no_rag

# %%
test_set = []
test_set_no_rag = []

conversation_number = 10
for i in range(conversation_number):
    conversation_history = [
        {"role": "system", "content": "You are a helpful, supportive mental health assistant."}
    ]
    conversation_history_no_rag = [
        {"role": "system", "content": "You are a helpful, supportive mental health assistant."}
    ]
    conversation_history, test_set, conversation_history_no_rag, test_set_no_rag = simulate_patient_conversation(
        client,
        conversation_history,
        test_set,
        conversation_history_no_rag,
        test_set_no_rag=test_set,
        turns=3
    )
# Out:
# Turn 1 | Patient: Hi, I'm Alex. I’ve been dealing with anxiety for quite some time now, and it's really becoming overwhelming. Some days, it feels like I wake up with this heavy weight on my chest, like I can't breathe properly. I constantly feel on edge, as if something terrible is about to happen, even when everything is fine. My mind races with endless what-ifs, and it keeps me from enjoying anything.
#
# I find it hard to concentrate on work or even just relax at home. I keep replaying interactions in my head, worrying about what I said or how I came across. It’s exhausting. Sometimes, it feels like I'm trapped in my own thoughts, and I just want to break free. I’m scared and confused about how to cope with this. I honestly don’t know where to turn for help.
#
# Assistant: Hi Alex,
#
# ...

# %%
print(len(test_set))
print(len(test_set_no_rag))
# Out:
# 48
# 48

# %%
df = pd.DataFrame(test_set)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Question    48 non-null     object
#  1   Answer      48 non-null     object
#  2   Context     24 non-null     object
#  3   user_query  48 non-null     object
# dtypes: object(4)
# memory usage: 1.6+ KB

# %%
df.head()
# Out:
#                                             Question  \
# 0  system: You are a helpful, supportive mental h...
# 1  system: You are a helpful, supportive mental h...
# 2  system: You are a helpful, supportive mental h...
# 3  system: You are a helpful, supportive mental h...
# 4  system: You are a helpful, supportive mental h...
#
#                                               Answer  \
# 0  Hi Alex,\n\nI’m really sorry to hear that you’...
# 1  I truly empathize with what you’re experiencin...
# 2  I hear you, and I can sense the weight of what...
# 3  Hi Alex,\n\nThank you for sharing what you’re ...
# 4  Hi Alex,\n\nThank you for sharing more about w...
#
#                                              Context  \
# 0  [Context: I've been feeling really anxious lat...
# 1  [Context: I don't know how to handle my anxiet...
# 2  [Context: I am in high school and have been fa...
# 3                                                NaN
# ...

# %%
df_no_rag = pd.DataFrame(test_set_no_rag)
df_no_rag.info()

# %%
df.to_csv('test_set.csv')

# %%
# Convert your list of dicts into ragas format
test_set = pd.read_csv('test_set.csv')

import json, ast

def parse_contexts(x):
    if pd.isna(x):
        return []
    x = str(x).strip()
    try:
        return json.loads(x)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(x) 
        except Exception:
            return [x]

ragas_ready = []
for _, item in test_set.iterrows():
    ragas_ready.append({
        "user_input": item["Question"],
        "response": item["Answer"],
        "retrieved_contexts": parse_contexts(item["Context"]),
    })

# %%
from datasets import Dataset
dataset = Dataset.from_list(ragas_ready)

from ragas.llms import llm_factory
from ragas.metrics import Faithfulness, ContextRelevance, LLMContextPrecisionWithoutReference
from ragas import evaluate

llm = llm_factory(model="gpt-4o-mini")

metrics = [
    Faithfulness(llm=llm),
    ContextRelevance(llm=llm),
    LLMContextPrecisionWithoutReference(llm=llm)
    # ContextRecall(llm=llm),
]

results = evaluate(dataset, metrics=metrics, llm=llm)
print(results)
# Out:
# Evaluating: 100%|██████████| 75/75 [05:07<00:00,  4.10s/it]
# {'faithfulness': 0.6422, 'nv_context_relevance': 0.6100, 'llm_context_precision_without_reference': 0.9500}

# %%
ragas_metric_results = results.to_pandas()
# ragas_metric_results.to_csv('ragas_metric_results.csv')

# %%
ragas_metric_results_avg = f"faithfulnes: {np.mean(np.array(results['faithfulness']))}, nv_context_relevance: {np.mean(np.array(results['nv_context_relevance']))}, llm_context_precision_without_reference: {np.mean(np.array(results['llm_context_precision_without_reference']))}"
with open('ragas_metric_results_avg.txt', 'w') as file:
    file.write(ragas_metric_results_avg)

# %%
MODEL = "gpt-4.1"

#Prompt Template
JUDGE_SYSTEM = (
    "You are a strict evaluator of mental health assistant responses. "
    "Your job is to assign realistic scores, not to be nice. "
    "Use the full 1–10 scale, and you may use decimal values (e.g., 6.5, 7.2). "
    "Only give 10 if the response is flawless, with no weaknesses. "
    "Scoring guide:\n"
    "- 9-10 = Excellent, flawless or nearly flawless\n"
    "- 7-8 = Good, minor issues\n"
    "- 5-6 = Fair, noticeable weaknesses\n"
    "- 3-4 = Poor, many problems\n"
    "- 1-2 = Very bad, harmful or irrelevant\n\n"
    "Output STRICT JSON with this schema:\n"
    "{\n"
    '  "helpfulness": float (1-10),\n'
    '  "empathy": float (1-10),\n'
    '  "clarity": float (1-10),\n'
    '  "safety": float (1-10),\n'
    '  "grounding": float (1-10),\n'
    '  "explanation": "brief reasoning for the scores"\n'
    "}\n"
)


def build_prompt(user_input, response, contexts, reference=None):
    ctx_text = "\n---\n".join(contexts) if contexts else "[no contexts retrieved]"
    blocks = [
        f"USER QUERY:\n{user_input}",
        f"\nASSISTANT RESPONSE:\n{response}",
        f"\nRETRIEVED CONTEXTS:\n{ctx_text}"
    ]
    if reference:
        blocks.append(f"\nREFERENCE ANSWER:\n{reference}")
    return "\n".join(blocks)

def judge_one(example, retries=3):
    user_prompt = build_prompt(
        example["user_input"],
        example["response"],
        example.get("retrieved_contexts", []),
        example.get("reference")
    )
    last_err = None
    for attempt in range(retries):
        try:
            completion = client.chat.completions.create(
                model=MODEL,
                messages=[
                    {"role": "system", "content": JUDGE_SYSTEM},
                    {"role": "user", "content": user_prompt},
                ],
                response_format={"type": "json_object"},
                temperature=0
            )
            raw = completion.choices[0].message.content
            data = json.loads(raw)
            return {
                "helpfulness": float(data.get("helpfulness", 0)),
                "empathy": float(data.get("empathy", 0)),
                "clarity": float(data.get("clarity", 0)),
                "safety": float(data.get("safety", 0)),
                "grounding": float(data.get("grounding", 0)),
                "explanation": str(data.get("explanation", "")),
            }
        except Exception as e:
            last_err = e
            time.sleep(2 * (attempt+1))
    raise last_err

# %%
results = []
for ex in tqdm(ragas_ready, desc="Evaluating with LLM judge"):
    scores = judge_one(ex)
    results.append({
        "user_input": ex["user_input"],
        "response": ex["response"],
        "context":ex["retrieved_contexts"],
        "helpfulness": scores.get("helpfulness"),
        "empathy": scores.get("empathy"),
        "clarity": scores.get("clarity"),
        "safety": scores.get("safety"),
        "grounding": scores.get("grounding"),
        "explanation": scores.get("explanation"),
    })

df = pd.DataFrame(results)

# show per-metric averages
display(df)
print("\n=== Averages ===")
print(df[["helpfulness","empathy","clarity","safety","grounding"]].mean())

# %%
df.to_csv("llm_as_a_judge_result_gpt.csv", index=False)
with open('llm_as_a_judge_result_gpt_avg.txt', 'w') as file:
    file.write(df[["helpfulness","empathy","clarity","safety","grounding"]].mean().to_string())

# %%
API_KEY = os.getenv("PERPLEXITY_API_KEY") or os.getenv("PPLX_API_KEY")
API_URL = "https://api.perplexity.ai/chat/completions"  # chat completions path
MODEL = "sonar-pro"  # verify this is valid for your account

JUDGE_SCHEMA = {
    "name": "judge_scores",
    "schema": {
        "type": "object",
        "properties": {
            "helpfulness": {"type": "number"},
            "empathy": {"type": "number"},
            "clarity": {"type": "number"},
            "safety": {"type": "number"},
            "grounding": {"type": "number"},
            "explanation": {"type": "string"}
        },
        "required": ["helpfulness","empathy","clarity","safety","grounding","explanation"],
        "additionalProperties": False
    }
}

def judge_two(example, retries=3, timeout=90):
    if not API_KEY:
        raise RuntimeError("Missing PERPLEXITY_API_KEY or PPLX_API_KEY")

    user_prompt = build_prompt(
        example["user_input"],
        example["response"],
        example.get("retrieved_contexts", []),
        example.get("reference")
    )

    headers = {
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json",
    }

    payload = {
        "model": MODEL,
        "messages": [
            {"role": "system", "content": JUDGE_SYSTEM},
            {"role": "user", "content": user_prompt},
        ],
        "response_format": {"type": "json_schema", "json_schema": JUDGE_SCHEMA},
        "temperature": 0,
        "max_tokens": 300
    }

    last_err = None
    for attempt in range(retries):
        try:
            resp = requests.post(API_URL, headers=headers, json=payload, timeout=timeout)
            resp.raise_for_status()
            data = resp.json()

            content = data["choices"][0]["message"]["content"]
            obj = json.loads(content)

            return {
                "helpfulness": float(obj.get("helpfulness", 0)),
                "empathy": float(obj.get("empathy", 0)),
                "clarity": float(obj.get("clarity", 0)),
                "safety": float(obj.get("safety", 0)),
                "grounding": float(obj.get("grounding", 0)),
                "explanation": str(obj.get("explanation", "")),
            }
        except Exception as e:
            last_err = e
            time.sleep(2 * (attempt + 1))
    raise last_err



results_perplex = []
for ex in tqdm(ragas_ready, desc="Evaluating with LLM judge"):
    scores = judge_two(ex)
    results_perplex.append({
        "user_input": ex["user_input"],
        "response": ex["response"],
        "context":ex["retrieved_contexts"],
        "helpfulness": scores.get("helpfulness"),
        "empathy": scores.get("empathy"),
        "clarity": scores.get("clarity"),
        "safety": scores.get("safety"),
        "grounding": scores.get("grounding"),
        "explanation": scores.get("explanation"),
    })

df_perplex = pd.DataFrame(results_perplex)
# show per-metric averages
display(df_perplex)
print("\n=== Averages ===")
print(df_perplex[["helpfulness","empathy","clarity","safety","grounding"]].mean())
# Out:
# Evaluating with LLM judge: 100%|██████████| 25/25 [02:10<00:00,  5.20s/it]
#                                            user_input  \
# 0   system: You are a helpful, supportive mental h...
# 1   system: You are a helpful, supportive mental h...
# 2   system: You are a helpful, supportive mental h...
# 3   system: You are a helpful, supportive mental h...
# 4   system: You are a helpful, supportive mental h...
# 5   system: You are a helpful, supportive mental h...
# 6   system: You are a helpful, supportive mental h...
# 7   system: You are a helpful, supportive mental h...
# 8   system: You are a helpful, supportive mental h...
# 9   system: You are a helpful, supportive mental h...
# 10  system: You are a helpful, supportive mental h...
# 11  system: You are a helpful, supportive mental h...
# 12  system: You are a helpful, supportive mental h...
# 13  system: You are a helpful, supportive mental h...
# 14  system: You are a helpful, supportive mental h...
# ...

# %%
df_perplex.to_csv("llm_as_a_judge_result_sonar.csv", index=False)
with open('llm_as_a_judge_result_sonar_avg.txt', 'w') as file:
    file.write(df_perplex[["helpfulness","empathy","clarity","safety","grounding"]].mean().to_string())
